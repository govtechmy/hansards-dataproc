# %%
import pdfplumber
pdf = pdfplumber.open("src_hansard/2020/06082020.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0d9b3a58b648> in <module>
#       1 import pdfplumber
# ----> 2 pdf = pdfplumber.open("src_hansard/2020/06082020.pdf")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pdfplumber/pdf.py in open(cls, path_or_fp, pages, laparams, password, strict_metadata)
#      69
#      70         if isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 71             stream: Union[BufferedReader, BytesIO] = open(path_or_fp, "rb")
#      72             stream_is_external = False
#      73         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'src_hansard/2020/06082020.pdf'
